# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import timedelta,datetime
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/Users/vishnusaibhadramraju/Downloads/city_market_tracker.tsv000.gz",compression='gzip', sep='\t')

# %%
df.head()
# Out:
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2020-04-01  2020-04-30               30       place               6
# 1   2018-09-01  2018-09-30               30       place               6
# 2   2018-04-01  2018-04-30               30       place               6
# 3   2018-09-01  2018-09-30               30       place               6
# 4   2023-04-01  2023-04-30               30       place               6
#
#    table_id is_seasonally_adjusted          region        city         state  \
# 0     21264                      f  Aspen Hill, MD  Aspen Hill      Maryland
# 1     17263                      f   Riverside, IA   Riverside          Iowa
# 2     18480                      f    Staunton, IL    Staunton      Illinois
# 3      4222                      f    Cornwall, PA    Cornwall  Pennsylvania
# 4     37021                      f     Fairfax, CA     Fairfax    California
#
#   state_code              property_type  property_type_id  median_sale_price  \
# 0         MD  Single Family Residential                 6           543474.0
# 1         IA            All Residential                -1           212550.0
# 2         IL  Single Family Residential                 6            97500.0
# 3         PA  Single Family Residential                 6           281007.0
# 4         CA  Single Family Residential                 6           335000.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0              -0.062976               0.221290           440999.0
# 1               1.632198                    NaN           141000.0
# 2               0.354167              -0.285714                NaN
# 3              -0.137989               0.003596           255000.0
# 4                    NaN               0.077170                NaN
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0               0.002270              -0.037120   249.369218         0.095230
# 1               0.177453                    NaN   109.684179         0.576360
# 2                    NaN                    NaN    61.416052         0.170381
# 3              -0.203792               0.146325   121.704450         0.006402
# 4                    NaN                    NaN   239.456755              NaN
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.149669        218.883415              0.023777
# 1              NaN        132.365564              0.381859
# 2         0.053746               NaN                   NaN
# 3        -0.123728        128.022541             -0.014216
# 4         0.017744               NaN                   NaN
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0             -0.010786        27.0        0.080000       -0.372093
# 1                   NaN         2.0        0.000000             NaN
# 2                   NaN         6.0        0.200000        1.000000
# 3              0.138751         7.0       -0.222222       -0.222222
# 4                   NaN         1.0             NaN       -0.500000
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0           27.0          -0.035714          -0.307692          31.0
# 1            1.0          -0.500000                NaN           2.0
# 2            NaN                NaN                NaN           NaN
# 3            8.0           0.600000           7.000000           7.0
# 4            2.0                NaN           1.000000           NaN
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0         -0.060606            -0.225       40.0       0.025641
# 1         -0.666667               NaN       11.0       0.000000
# 2               NaN               NaN        1.0       0.000000
# 3          0.166667             6.000       14.0      -0.066667
# 4               NaN               NaN        NaN            NaN
#
#    inventory_yoy  months_of_supply  months_of_supply_mom  \
# 0       0.250000               1.5                  -0.1
# 1            NaN               5.5                   0.0
# 2      -0.909091               0.2                   0.0
# 3       0.076923               2.0                   0.3
# 4            NaN               NaN                   NaN
#
#    months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  \
# 0                   0.8         8.0            -7.0           -11.0
# 1                   NaN       595.0           567.0             NaN
# 2                  -3.5        65.0             NaN          -199.0
# 3                   0.6       132.0           101.0           104.0
# 4                   NaN         8.0             NaN           -18.0
#
#    avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  \
# 0          1.006563              0.001105              0.005695
# 1          0.936765              0.043346                   NaN
# 2          0.883412             -0.046591             -0.071837
# 3          0.963201             -0.032614             -0.027382
# 4          1.000000                   NaN             -0.046365
#
#    sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0         0.481481             0.081481             0.062877     0.125000
# 1         0.500000             0.500000                  NaN          NaN
# 2         0.000000             0.000000             0.000000          NaN
# 3         0.142857            -0.301587            -0.190476     0.428571
# 4         0.000000                  NaN            -1.000000          NaN
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0        -0.105769         -0.15625                 0.444444
# 1              NaN              NaN                 0.000000
# 2              NaN              NaN                      NaN
# 3         0.361905              NaN                 0.750000
# 4              NaN              NaN                 0.500000
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 0                    -0.162698                     -0.17094
# 1                     0.000000                          NaN
# 2                          NaN                          NaN
# 3                     0.150000                      0.75000
# 4                          NaN                     -0.50000
#
#   parent_metro_region  parent_metro_region_metro_code         last_updated
# 0       Frederick, MD                           23224  2024-05-19 14:23:50
# 1       Iowa City, IA                           26980  2024-05-19 14:23:50
# 2       St. Louis, MO                           41180  2024-05-19 14:23:50
# 3         Lebanon, PA                           30140  2024-05-19 14:23:50
# 4     Bakersfield, CA                           12540  2024-05-19 14:23:50

# %%
def lambda_handler(df):
     # Remove commas from the 'city' column
    df['city'] = df['city'].str.replace(',', '')
    cols = ['period_begin','period_end','period_duration', 'region_type', 'region_type_id', 'table_id',
    'is_seasonally_adjusted', 'city', 'state', 'state_code', 'property_type', 'property_type_id',
    'median_sale_price', 'median_list_price', 'median_ppsf', 'median_list_ppsf', 'homes_sold',
    'inventory', 'months_of_supply', 'median_dom', 'avg_sale_to_list', 'sold_above_list', 'parent_metro_region_metro_code', 
    'last_updated']
    df = df[cols]
    
    df = df.dropna()
    
    #let's change the period_begin and period_end to date time object and extract years and month.
    df['period_begin'] = pd.to_datetime(df['period_begin'])
    df['period_end'] = pd.to_datetime(df['period_end'])
    
    df["period_begin_in_years"] = df['period_begin'].dt.year
    df["period_end_in_years"] = df['period_end'].dt.year

    df["period_begin_in_months"] = df['period_begin'].dt.month
    df["period_end_in_months"] = df['period_end'].dt.month
    
    #let's map the month number to their respective month name.
    month_dict = {
        "period_begin_in_months": {
            1 : "Jan",
             2 :  "Feb",
             3: "Mar",
             4: "Apr",
             5: "May",
             6: "Jun",
             7: "Jul",
             8: "Aug",
             9: "Sep",
             10: "Oct",
             11: "Nov",
             12: "Dec",
        },
        "period_end_in_months": {
            1 : "Jan",
             2 :  "Feb",
             3: "Mar",
             4: "Apr",
             5: "May",
             6: "Jun",
             7: "Jul",
             8: "Aug",
             9: "Sep",
             10: "Oct",
             11: "Nov",
             12: "Dec"
        }}
    df = df.replace(month_dict)
    print('Num of rows:', len(df))
    print('Num of cols:', len(df.columns))
    return df

# %%
df1 = lambda_handler(df)
df1.head()
# Out:
# Num of rows: 4211393
# Num of cols: 28
#    period_begin period_end  period_duration region_type  region_type_id  \
# 0    2020-04-01 2020-04-30               30       place               6
# 1    2018-09-01 2018-09-30               30       place               6
# 3    2018-09-01 2018-09-30               30       place               6
# 7    2016-07-01 2016-07-31               30       place               6
# 10   2021-01-01 2021-01-31               30       place               6
#
#     table_id is_seasonally_adjusted        city         state state_code  \
# 0      21264                      f  Aspen Hill      Maryland         MD
# 1      17263                      f   Riverside          Iowa         IA
# 3       4222                      f    Cornwall  Pennsylvania         PA
# 7       9272                      f    Hueytown       Alabama         AL
# 10     19746                      f   Watertown     Tennessee         TN
#
#                 property_type  property_type_id  median_sale_price  \
# 0   Single Family Residential                 6           543474.0
# 1             All Residential                -1           212550.0
# 3   Single Family Residential                 6           281007.0
# 7             All Residential                -1           122595.0
# 10  Single Family Residential                 6           239000.0
#
#     median_list_price  median_ppsf  median_list_ppsf  homes_sold  inventory  \
# 0            440999.0   249.369218        218.883415        27.0       40.0
# 1            141000.0   109.684179        132.365564         2.0       11.0
# 3            255000.0   121.704450        128.022541         7.0       14.0
# 7             92200.0    61.197169         66.204872        20.0      110.0
# 10           244450.0   145.200486        196.596539         1.0        5.0
#
#     months_of_supply  median_dom  avg_sale_to_list  sold_above_list  \
# 0                1.5         8.0          1.006563         0.481481
# 1                5.5       595.0          0.936765         0.500000
# 3                2.0       132.0          0.963201         0.142857
# 7                5.5        91.0          0.953411         0.200000
# 10               5.0        75.0          0.919584         0.000000
#
#     parent_metro_region_metro_code         last_updated  \
# 0                            23224  2024-05-19 14:23:50
# 1                            26980  2024-05-19 14:23:50
# 3                            30140  2024-05-19 14:23:50
# 7                            13820  2024-05-19 14:23:50
# 10                           34980  2024-05-19 14:23:50
#
#     period_begin_in_years  period_end_in_years period_begin_in_months  \
# 0                    2020                 2020                    Apr
# 1                    2018                 2018                    Sep
# 3                    2018                 2018                    Sep
# 7                    2016                 2016                    Jul
# 10                   2021                 2021                    Jan
#
#    period_end_in_months
# 0                   Apr
# 1                   Sep
# 3                   Sep
# 7                   Jul
# 10                  Jan

# %%
now = datetime.now()
date_now_string = now.strftime("%d%m%Y%H%M%S")
file_str = 'redfin_data_' + date_now_string
df1.to_csv(f"{file_str}.csv", index=False)
output_file_path = f"/Users/vishnusaibhadramraju/Downloads/{file_str}.csv"

# %%
output_file_path
# Out:
# '/Users/vishnusaibhadramraju/Downloads/redfin_data_02062024131755.csv'

# %%
# Out:
# (5354687, 58)
